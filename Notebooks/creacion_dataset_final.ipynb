# %%
import numpy as np
import pandas as pd
import pickle
import re
import math

import limpieza_datos as l
import imputaciones as i
import tratamiento_webscrapping as w
import imputacion_numerica as n

# %% [markdown]
# ### APLICAMOS LAS FUNCIONES DEL WEBSCRAPPING A LOS DATOS DE CHRONO24

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_omega.pkl','rb')
omega= pickle.load(fh)
fh.close()

# %%
omega = w.limpieza_webscrap(omega)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_tissot.pkl','rb')
tissot= pickle.load(fh)
fh.close()

# %%
tissot = w.limpieza_webscrap(tissot)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_casio.pkl','rb')
casio= pickle.load(fh)
fh.close()

# %%
casio = w.limpieza_webscrap(casio)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_casio2.pkl','rb')
casio2= pickle.load(fh)
fh.close()

# %%
casio2 = w.limpieza_webscrap(casio2)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_hamilton.pkl','rb')
hamilton= pickle.load(fh)
fh.close()

# %%
hamilton = w.limpieza_webscrap(hamilton)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_hamilton2.pkl','rb')
hamilton2= pickle.load(fh)
fh.close()

# %%
hamilton2 = w.limpieza_webscrap(hamilton2)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_hublot.pkl','rb')
hublot= pickle.load(fh)
fh.close()

# %%
hublot = w.limpieza_webscrap(hublot)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_hublot2.pkl','rb')
hublot2= pickle.load(fh)
fh.close()

# %%
hublot2 = w.limpieza_webscrap(hublot2)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_cartier.pkl','rb')
cartier= pickle.load(fh)
fh.close()

# %%
cartier = w.limpieza_webscrap(cartier)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_cartier2.pkl','rb')
cartier2= pickle.load(fh)
fh.close()

# %%
cartier2 = w.limpieza_webscrap(cartier2)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_patek.pkl','rb')
patek= pickle.load(fh)
fh.close()

# %%
patek = w.limpieza_webscrap(patek)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_patek2.pkl','rb')
patek2= pickle.load(fh)
fh.close()

# %%
patek2 = w.limpieza_webscrap(patek2)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_rolex.pkl','rb')
rolex= pickle.load(fh)
fh.close()

# %%
rolex = w.limpieza_webscrap(rolex)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_rolex2.pkl','rb')
rolex2= pickle.load(fh)
fh.close()

# %%
rolex2 = w.limpieza_webscrap(rolex2)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_seiko.pkl','rb')
seiko= pickle.load(fh)
fh.close()

# %%
seiko = w.limpieza_webscrap(seiko)

# %%
fh = open('C:/Users/Mario Vegas/Desktop/BOOTCAMP DATA/PROYECTO FINAL/Datos/lista_richardmille.pkl','rb')
richard= pickle.load(fh)
fh.close()

# %%
richard = w.limpieza_webscrap(richard)

# %% [markdown]
# ### CREACIÓN DEL DATASET FINAL

# %%
data = pd.concat([omega, tissot, seiko, richard, casio, casio2, hamilton, hamilton2, patek, patek2, hublot, hublot2, rolex, rolex2, cartier, cartier2] , axis = 0)

# %%
data
# Out:
#     Código del anuncio    Marca                      (Reloj) Modelo  \
# 0               E16096    Omega  Speedmaster Professional Moonwatch
# 1               DWLBK5    Omega                   Seamaster PloProf
# 2               F8W575    Omega               Seamaster Diver 300 M
# 3               FIQVB7    Omega                       Seamaster 300
# 4               F37DC4    Omega                Seamaster Aqua Terra
# ..                 ...      ...                                 ...
# 420             ED4K01  Cartier                  21 Must de Cartier
# 421             CS8CT8  Cartier                               Pasha
# 422             F7TUW0  Cartier                    Ballon Bleu 33mm
# 423             AIW8S9  Cartier                            Panthère
# 424             EKALN5  Cartier                             Tank MC
#
#     Número de referencia Código del comerciante  \
# 0        145.022 - 69 ST                    NaN
# 1                166.077                  21c21
# ...

# %% [markdown]
# ### APLICAMOS LAS FUNCIONES DE LIMPIEZA AL DATASET

# %%
data = l.limpiar_datos(data)

# %%
data
# Out:
#        Marca                              Modelo Material de la pulsera  \
# 0      Omega  Speedmaster Professional Moonwatch                  Acero
# 1      Omega                   Seamaster PloProf                 Caucho
# 2      Omega               Seamaster Diver 300 M                  Acero
# 3      Omega                       Seamaster 300                   Piel
# 4      Omega                Seamaster Aqua Terra                  Acero
# ..       ...                                 ...                    ...
# 420  Cartier                  21 Must de Cartier        Piel de tiburon
# 421  Cartier                               Pasha       Piel de aligátor
# 422  Cartier                    Ballon Bleu 33mm            Acero y oro
# 423  Cartier                            Panthère           Oro amarillo
# 424  Cartier                             Tank MC       Piel de aligátor
#
#                                                 Estado  \
# ...

# %% [markdown]
# ### APLICAMOS LAS FUNCIONES DE IMPUTACIÓN DE VALORES NULOS

# %%
data = i.imputacion(data)

# %%
data
# Out:
#        Marca                              Modelo Material de la pulsera  \
# 0      Omega  Speedmaster Professional Moonwatch                  Acero
# 1      Omega                   Seamaster PloProf                 Caucho
# 2      Omega               Seamaster Diver 300 M                  Acero
# 3      Omega                       Seamaster 300                   Piel
# 4      Omega                Seamaster Aqua Terra                  Acero
# ..       ...                                 ...                    ...
# 420  Cartier                  21 Must de Cartier        Piel de tiburon
# 421  Cartier                               Pasha       Piel de aligátor
# 422  Cartier                    Ballon Bleu 33mm            Acero y oro
# 423  Cartier                            Panthère           Oro amarillo
# 424  Cartier                             Tank MC       Piel de aligátor
#
#                                                 Estado  \
# ...

# %%
pd.options.mode.chained_assignment = None

# %% [markdown]
# ### APLICAMOS LAS FUNCIONES DE IMPUTACIÓN DE VALORES NULOS A LAS VARIABLES NUMÉRICAS

# %%
data = n.imputacion_numerica(data)

# %%
data
# Out:
#        Marca                              Modelo Material de la pulsera  \
# 0      Omega  Speedmaster Professional Moonwatch                  Acero
# 1      Omega                   Seamaster PloProf                 Caucho
# 2      Omega               Seamaster Diver 300 M                  Acero
# 3      Omega                       Seamaster 300                   Piel
# 4      Omega                Seamaster Aqua Terra                  Acero
# ..       ...                                 ...                    ...
# 420  Cartier                  21 Must de Cartier        Piel de tiburon
# 421  Cartier                               Pasha       Piel de aligátor
# 422  Cartier                    Ballon Bleu 33mm            Acero y oro
# 423  Cartier                            Panthère           Oro amarillo
# 424  Cartier                             Tank MC       Piel de aligátor
#
#                                                 Estado  \
# ...

# %% [markdown]
# ### GUARDAMOS EL DATASET FINAL EN UN PICKLE

# %%
fh = open("dataframe_final.pkl","wb")
pickle.dump(data,fh)
fh.close()
